# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from langchain_core.prompts import PromptTemplate, FewShotPromptTemplate
from dotenv import load_dotenv
import os

# %%
load_dotenv()

api_key = os.getenv("API_KEY")
endpoint = os.getenv("OPENAI_ENDPOINT")
model_name = "gpt-4o-mini"

# ChatOpenAI (more standard code)
llm = ChatOpenAI(
    base_url=endpoint,
    api_key=api_key,
    model=model_name,
    temperature=0.0
)

# %%
response = llm.invoke("is Turkey in europe")

print(response.content) # content str only
# Out:
# Turkey is a transcontinental country, meaning it is located on two continents: Europe and Asia. The smaller portion of Turkey, known as East Thrace, is situated in southeastern Europe, while the larger part, Anatolia (or Asia Minor), is located in western Asia. The city of Istanbul, Turkey's largest city, straddles both continents, with part of it in Europe and part in Asia.
