# %% [markdown]
# ## Establish OpenAI Client

# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv("API_KEY")
endpoint = os.getenv("OPENAI_ENDPOINT")

client = OpenAI(
            api_key=api_key,
            base_url=endpoint
        )

# %% [markdown]
# ## Create reusable function to call LLMs

# %%
system_prompt = """Act as a B2B content creator.
Create marketing campaign texts to reach the audience of the company CultPass,
which has developed a benefits card for companies to offer their employees more culture, 
such as museums, art galleries, concerts, and similar experiences.
Do not provide any explanations, only the material to be sent.
"""
def create_content(query:str,
                   client:OpenAI, 
                   system_prompt:str,
                   model:str,
                   temperature:float)->str:
    messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": query},
    ]
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=temperature,
    )

    # Experiment returning the full response to understand the object
    content = response.choices[0].message.content

    return content

def create_content2(query:str,
                   client:OpenAI, 
                   system_prompt:str,
                   model:str,
                   temperature:float):
    messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": query},
    ]
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=temperature,
    )

    # Experiment returning the full response to understand the object
    content = response.choices[0].message

    return content

# %% [markdown]
# ## Test the Function

# %%
model = "gpt-4o-mini"
temperature = 0.3

# Marketing Analyst input
analyst_query = "Create an instagram post for clients in the automotive industry"
content = create_content(
    query=analyst_query,
    client=client,
    system_prompt=system_prompt,
    model=model,
    temperature=temperature
)
print(content)
# Out:
# **📸 [Image of a vibrant art gallery or a live concert scene]**
#
# 🌟 Drive Your Team’s Creativity with CultPass! 🌟
#
# In the fast-paced automotive industry, innovation is key. But where does inspiration come from? 🚗💡
#
# With CultPass, you can fuel your employees' creativity by offering them access to a world of cultural experiences! From art galleries to live concerts, our benefits card opens the door to inspiration that drives success.
#
# ✨ Why Choose CultPass?
# - Boost employee morale and satisfaction
# - Foster creativity and fresh ideas
# - Enhance team bonding through shared experiences
#
# Let’s shift gears and take your team’s cultural engagement to the next level!
#
# 🔗 [Link in bio to learn more about CultPass]
#
# #CultPass #AutomotiveInnovation #EmployeeEngagement #CulturalBenefits #InspirationOnWheels

# %%
type(content)
# Out:
# str

# %%
model = "gpt-4o-mini"
temperature = 0.3

# Marketing Analyst input
analyst_query = "Create an instagram post for clients in the automotive industry"
message = create_content2(
    query=analyst_query,
    client=client,
    system_prompt=system_prompt,
    model=model,
    temperature=temperature
)
print(type(message))
print(message.content)
# Out:
# <class 'openai.types.chat.chat_completion_message.ChatCompletionMessage'>
# **📸 [Image of a vibrant art gallery with employees enjoying a cultural outing]**
#
# **Caption:**
#
# 🚗✨ Drive your team's creativity and motivation to new heights with CultPass!
#
# In the fast-paced automotive industry, innovation is key. Give your employees the chance to recharge and find inspiration through cultural experiences. With CultPass, they can explore museums, art galleries, concerts, and much more—all while enhancing their well-being and team spirit.
#
# 💡 Why choose CultPass for your team?
# - Boost creativity and collaboration
# - Foster a positive workplace culture
# - Enhance employee satisfaction and retention
#
# Join the movement towards a more culturally enriched workforce. Let’s put the "art" in automotive!
#
# 🔗 [Link to learn more about CultPass]
#
# #CultPass #AutomotiveIndustry #EmployeeBenefits #CulturalExperiences #TeamInspiration #WorkplaceWellbeing
