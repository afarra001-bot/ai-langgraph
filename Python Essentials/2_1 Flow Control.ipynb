# %% [markdown]
# # 🔹Title
#  -  XXX
#  -  YYY
#  -  ZZZ

# %% [markdown]
# # 🔹Title
#  -  XXX
#  -  YYY
#  -  ZZZ

# %% [markdown]
# # 🔹Title
#  -  XXX
#  -  YYY
#  -  ZZZ

# %% [markdown]
# # 🔹Title
#  -  XXX
#  -  YYY
#  -  ZZZ

# %% [markdown]
# # 🔹Range and Enumerate
#  -  Tuple unpacking also makes an appearance in a built-in looping method: enumerate, which produces an iterator of pairs of (index, value) from an iterable of values
#  -  The existence of this function means that you should almost never use for i in range(len(sequence)) to get indices to use to index into a sequence.

# %%
# range()
for i in range(10):
    print(i)

# %%
# Tuple unpacking also makes an appearance in a built-in looping method: enumerate, 
# which produces an iterator of pairs of (index, value) from an iterable of values:

for index, color in enumerate(['red','green','blue']):
    print(index, color)

# =>
# 0 red
# 1 green
# 2 blue

# %% [markdown]
# # 🔹Title
#  -  XXX
#  -  YYY
#  -  ZZZ
