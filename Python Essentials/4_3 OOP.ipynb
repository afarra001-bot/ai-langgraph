# %% [markdown]
# # 🔹Title
#  -  XXX
#  -  YYY
#  -  ZZZ

# %% [markdown]
# # 🔹Title
#  -  XXX
#  -  YYY
#  -  ZZZ

# %% [markdown]
# # 🔹Title
#  -  XXX
#  -  YYY
#  -  ZZZ

# %% [markdown]
# # 🔹Title
#  -  XXX
#  -  YYY
#  -  ZZZ

# %% [markdown]
# # 🔹Title
#  -  XXX
#  -  YYY
#  -  ZZZ

# %% [markdown]
# # 🔹Title
#  -  XXX
#  -  YYY
#  -  ZZZ
